# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv("data (1).csv")

X = df.iloc[:,0]
y= df.iloc[:,1]
plt.scatter(X,y)

# %% [markdown]
# # Building THe Model

# %%
m = 0 # slope
c = 0 # constant
# Learning Rate
L = 0.0001

epochs =1000

# Gradient Descent
for i in range(epochs):
    y_pred = m*X +c    # straight line equation
    D_m = (-2/n) * sum(X*(y-y_pred))
    D_c = (-2/n) * sum(y-y_pred)
    m = m-L*D_m
    c= c-L*D_c

# Printing the slope and constant 
print(m,c)
# Out:
# 1.4796491688889395 0.10148121494753734

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()
